# %% [markdown]
# TIMELINE FOR OUR PROJECT!

# %% [markdown]
# Sprint 1 (6)
#
# 1. Find our data
# 2. Preprocess

# %% [markdown]
# Sprint 2 (7)
# 1. Finish preprocessing
# 2. LASSO or Ridge Regression for feature selection (answers part of question 1 What are the most important internal and external features in predicting rental prices? (Thisan be at the granularity of the groups’ choosing))

# %% [markdown]
# Sprint 3 (8)
# 1. Find out more about surrounding features to houses (train stations, car routes, etc, answers more of question 1)

# %% [markdown]
# Sprint 4 (9)
# 1. Begin modelling, for a 5-year period minimum
# 3. Check normality
# 2. Linear Regression
# 4. start working on slides

# %% [markdown]
# Sprint 5
# 1. TBD, whatever needs to be done from last 4 sprints
# 2. Main time to work on slides

# %% [markdown]
# Sprint 6 (10)
# 1. summarise answers for 5/3 year predictions, answer our big 3
